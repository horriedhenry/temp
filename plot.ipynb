# %% [markdown]
# 3b

# %%
#Plot the following functions: h11(x1, x2), h12(x1, x2), h13(x1, x2), h14(x1, x2), h21(x1, x2),
#h22(x1, x2), h31(x1, x2) and f(x1, x2) for x1 ∈ (−5, 5) and x2 ∈ (−5, 5)

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D

# %%
def h11(x1,x2):
    return 1/(1 + np.exp(-(x1 + 50*x2 + 100)))

def h12(x1,x2):
    return 1/(1 + np.exp(-(x1 + 50*x2 - 100)))

def h13(x1,x2):
    return 1/(1 + np.exp(-(50*x1 + x2 + 100)))

def h14(x1,x2):
    return 1/(1 + np.exp(-(50*x1 + x2 - 100)))

def h21(x1,x2):
    return h11(x1,x2) - h12(x1,x2)

def h22(x1,x2):
    return h13(x1,x2) - h14(x1,x2)

def h31(x1,x2):
    return h21(x1,x2) + h22(x1,x2)

def f(x1,x2):
    return 1/(1 + np.exp(-(100*h31(x1,x2) - 200)))

# %%
x1 = np.arange(-5,5,0.01)
x2 = np.arange(-5,5,0.01)
X, Y = np.meshgrid(x1, x2)

# %%
Z = h11(X, Y)
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('h11');
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_13896\2086689345.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
Z = h12(X, Y)
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x_1')
ax.set_ylabel('x_2')
ax.set_zlabel('h12');
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_13896\570388372.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
Z = h13(X, Y)
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('h13');
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_13896\2200381412.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
Z = h14(X, Y)
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('h14');
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_13896\1943829198.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
Z = h21(X, Y)
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('h21');
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_13896\2673434241.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
Z = h22(X, Y)
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('h22');
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_13896\112725515.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
Z = h31(X, Y)
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('h31');
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_13896\4018204565.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
Z = f(X, Y)
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('f');
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_13896\3398338643.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
